# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 4.14.3

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
l=[]
for i in range(1648):
    x=str(i)
    s='0'*(10-len(x))+x+'.txt'
    f=open("data/"+s, "r")
    for x in f:
        l.append(x.split())

# %%
l=np.array(l)

# %%
d=pd.DataFrame(l)

# %%
d.head()
# Out:
#                 0                1                2         3          4   \
# 0  49.011226504293  8.4228780174545  112.79475402832  0.025982  -0.013047
# 1  49.011226239275  8.4228781589868   112.7972869873  0.026346  -0.013242
# 2  49.011225920569  8.4228782904009  112.79761505127  0.026712  -0.013469
# 3  49.011225600813  8.4228784215946  112.79777526855  0.027125  -0.013598
# 4  49.011225334619  8.4228785631695  112.80041503906  0.027577  -0.013621
#
#                  5                 6                 7                8   \
# 0  -1.2879616732051  -3.5890958450448  0.95452975301369  3.7134915845511
# 1  -1.2863176732051  -3.5836664682881  0.95526029006163  3.7083725408816
# 2  -1.2849146732051  -3.5784214980449  0.95603124655239  3.7034426219095
# 3  -1.2833926732051  -3.5733632733382  0.95679155956953  3.6986878161395
# 4  -1.2819196732051  -3.5682987823374   0.9577678256341  3.6939879768498
#
#                   9   ...                  20                  21  \
# ...

# %%
c=[]
f=open("dataformat.txt", "r")
for i in f:
    #print(i.split(':')[0])
    c.append(i.split(':')[0])

# %%
c
# Out:
# ['lat',
#  'lon',
#  'alt',
#  'roll',
#  'pitch',
#  'yaw',
#  'vn',
#  've',
#  'vf',
#  'vl',
#  'vu',
#  'ax',
#  'ay',
#  'az',
#  'af',
#  'al',
#  'au',
#  'wx',
#  'wy',
#  'wz',
#  'wf',
#  'wl',
#  'wu',
#  'pos_accuracy',
#  'vel_accuracy',
#  'navstat',
#  'numsats',
#  'posmode',
#  'velmode',
#  'orimode']

# %%
di={}
for i in range(len(c)):
    di[i]=c[i]

# %%
di
# Out:
# {0: 'lat',
#  1: 'lon',
#  2: 'alt',
#  3: 'roll',
#  4: 'pitch',
#  5: 'yaw',
#  6: 'vn',
#  7: 've',
#  8: 'vf',
#  9: 'vl',
#  10: 'vu',
#  11: 'ax',
#  12: 'ay',
#  13: 'az',
#  14: 'af',
#  15: 'al',
#  16: 'au',
#  17: 'wx',
#  18: 'wy',
#  19: 'wz',
#  20: 'wf',
#  21: 'wl',
#  22: 'wu',
#  23: 'pos_accuracy',
#  24: 'vel_accuracy',
#  25: 'navstat',
#  26: 'numsats',
#  27: 'posmode',
#  28: 'velmode',
#  29: 'orimode'}

# %%
d.rename(columns=di, inplace = True)

# %%
d.head()
# Out:
#                lat              lon              alt      roll      pitch  \
# 0  49.011226504293  8.4228780174545  112.79475402832  0.025982  -0.013047
# 1  49.011226239275  8.4228781589868   112.7972869873  0.026346  -0.013242
# 2  49.011225920569  8.4228782904009  112.79761505127  0.026712  -0.013469
# 3  49.011225600813  8.4228784215946  112.79777526855  0.027125  -0.013598
# 4  49.011225334619  8.4228785631695  112.80041503906  0.027577  -0.013621
#
#                 yaw                vn                ve               vf  \
# 0  -1.2879616732051  -3.5890958450448  0.95452975301369  3.7134915845511
# 1  -1.2863176732051  -3.5836664682881  0.95526029006163  3.7083725408816
# 2  -1.2849146732051  -3.5784214980449  0.95603124655239  3.7034426219095
# 3  -1.2833926732051  -3.5733632733382  0.95679155956953  3.6986878161395
# 4  -1.2819196732051  -3.5682987823374   0.9577678256341  3.6939879768498
#
#                   vl  ...                  wf                  wl  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1648 entries, 0 to 1647
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lat           1648 non-null   object
#  1   lon           1648 non-null   object
#  2   alt           1648 non-null   object
#  3   roll          1648 non-null   object
#  4   pitch         1648 non-null   object
#  5   yaw           1648 non-null   object
#  6   vn            1648 non-null   object
#  7   ve            1648 non-null   object
#  8   vf            1648 non-null   object
#  9   vl            1648 non-null   object
#  10  vu            1648 non-null   object
#  11  ax            1648 non-null   object
#  12  ay            1648 non-null   object
#  13  az            1648 non-null   object
#  14  af            1648 non-null   object
#  15  al            1648 non-null   object
#  16  au            1648 non-null   object
#  17  wx            1648 non-null   object
# ...

# %%
def imp(d,*args):
    x=args[0]
    if(x==-1):
        try:
            return int(d)
        except:
            return d
    else:
        try:
            return float(d)
        except:
            return d

# %%
for i in d.columns:
    x=(d[i][0].find('.'),0)
    #print(i,x)
    d[i]=d[i].apply(imp,args=x)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1648 entries, 0 to 1647
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lat           1648 non-null   float64
#  1   lon           1648 non-null   float64
#  2   alt           1648 non-null   float64
#  3   roll          1648 non-null   float64
#  4   pitch         1648 non-null   float64
#  5   yaw           1648 non-null   float64
#  6   vn            1648 non-null   float64
#  7   ve            1648 non-null   float64
#  8   vf            1648 non-null   float64
#  9   vl            1648 non-null   float64
#  10  vu            1648 non-null   float64
#  11  ax            1648 non-null   float64
#  12  ay            1648 non-null   float64
#  13  az            1648 non-null   float64
#  14  af            1648 non-null   float64
#  15  al            1648 non-null   float64
#  16  au            1648 non-null   float64
# ...

# %%
plt.plot(d['wx'])

# %%
plt.plot(d['wy'])

# %%
plt.plot(d['wz'])

# %%
plt.plot(d['ax'])

# %%
plt.plot(d['ay'])

# %%
plt.plot(d['az'])

# %%
plt.plot(d['vf'])

# %%
plt.plot(d['vu'])

# %%
plt.plot(d['vl'])

# %%
d['sn']=np.array(list(range(len(d))))

# %%
d.iplot(kind='line',x='sn',y='ax',size=10)
# Out:
# <div>                            <div id="cf7cf259-59b3-4d64-b9f5-c3be1fe0d80c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import numpy as np
from scipy.signal import argrelextrema

# %%
argrelextrema(np.array(d['ax']), np.greater)
# Out:
# (array([   7,   15,   28,   31,   39,   51,   56,   63,   81,   88,  101,
#          108,  112,  124,  130,  144,  147,  151,  154,  157,  160,  163,
#          173,  179,  187,  191,  198,  205,  220,  227,  234,  241,  244,
#          247,  251,  254,  259,  266,  269,  272,  279,  287,  293,  295,
#          300,  303,  307,  314,  322,  329,  338,  345,  351,  357,  366,
#          373,  389,  393,  400,  410,  416,  422,  442,  445,  453,  456,
#          460,  469,  476,  483,  486,  490,  498,  505,  511,  518,  535,
#          540,  543,  546,  553,  557,  559,  562,  571,  580,  584,  587,
#          595,  601,  613,  616,  620,  623,  625,  635,  637,  643,  646,
#          657,  659,  667,  669,  672,  674,  679,  686,  692,  695,  701,
#          704,  708,  712,  715,  717,  721,  724,  731,  738,  744,  748,
#          756,  762,  797,  803,  810,  816,  823,  826,  829,  833,  846,
#          851,  854,  862,  865,  868,  874,  880,  886,  892,  899,  906,
# ...

# %%
argrelextrema(np.array(d['ax']), np.less)
# Out:
# (array([  11,   25,   29,   34,   42,   53,   58,   77,   82,   89,  104,
#          111,  114,  125,  135,  146,  149,  152,  155,  159,  162,  172,
#          176,  185,  190,  193,  201,  216,  222,  229,  236,  242,  245,
#          248,  253,  255,  264,  268,  271,  277,  284,  291,  294,  297,
#          302,  304,  311,  318,  326,  333,  340,  347,  355,  362,  368,
#          375,  391,  394,  408,  415,  419,  425,  443,  446,  454,  458,
#          466,  474,  481,  485,  488,  495,  502,  510,  517,  531,  539,
#          541,  544,  551,  554,  558,  560,  569,  576,  583,  585,  590,
#          599,  610,  615,  618,  621,  624,  630,  636,  640,  644,  651,
#          658,  661,  668,  671,  673,  675,  683,  690,  693,  696,  703,
#          706,  709,  713,  716,  719,  723,  726,  733,  740,  746,  753,
#          760,  792,  801,  805,  814,  820,  824,  827,  832,  839,  850,
#          852,  856,  863,  866,  869,  876,  883,  888,  895,  903,  909,
# ...

# %%
d.iplot(kind='line',x='sn',y='wz',size=10)
# Out:
# <div>                            <div id="a1257bca-6cd5-4c55-b699-a575a2f4125c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d.iplot(kind='line',x='sn',y='vf',size=10)
# Out:
# <div>                            <div id="68f53904-2e59-4d59-ae75-a0a892d44204" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ma=argrelextrema(np.array(d['vf']), np.greater)
ma=ma[0]
ma
# Out:
# array([ 158,  199,  211,  228,  289,  301,  309,  316,  323,  329,  338,
#         527,  534,  782, 1040, 1047, 1062, 1212, 1299, 1306, 1311, 1320,
#        1323, 1632], dtype=int64)

# %%
mi=argrelextrema(np.array(d['vf']), np.less)
mi=mi[0]
mi
# Out:
# array([ 156,  197,  202,  225,  229,  298,  305,  312,  319,  328,  337,
#         340,  533,  729,  872, 1041, 1048, 1063, 1295, 1301, 1307, 1318,
#        1321, 1327], dtype=int64)

# %%
a=[]
b=[]
for i in range(len(ma)-1):
    x=-1*(d['vf'][mi[i]]-d['vf'][ma[i]])*100
    x1=((d['vf'][mi[i]]-d['vf'][ma[i]])/(mi[i]-ma[i]))*1000
    y=-1*(d['vf'][ma[i]]-d['vf'][mi[i+1]])*100
    y1=((d['vf'][ma[i]]-d['vf'][mi[i+1]])/(ma[i]-mi[i+1]))*1000
    a.append([round(x,4),x1,mi[i],ma[i]])
    b.append([round(y,4),y1,ma[i],mi[i+1]])
    #print("Incs: "+str(round(x1,4)),str(mi[i]),str(ma[i]))
    #print("Decs: "+str(round(y1,4)),str(ma[i]),str(mi[i+1]))
# Out:
# Incs: 0.5712 156 158
# Decs: -2.1491 158 197
# Incs: 0.2895 197 199
# Decs: -2.5313 199 202
# Incs: 2.1729 202 211
# Decs: -1.8257 211 225
# Incs: 0.7377 225 228
# Decs: -0.018 228 229
# Incs: 2.5372 229 289
# Decs: -1.0689 289 298
# Incs: 0.8248 298 301
# Decs: -1.7382 301 305
# Incs: 0.8872 305 309
# Decs: -0.7314 309 312
# Incs: 1.1728 312 316
# Decs: -1.5866 316 319
# Incs: 0.8896 319 323
# Decs: -1.7061 323 328
# Incs: 0.0015 328 329
# Decs: -0.8366 329 337
# Incs: 0.3594 337 338
# Decs: -0.5843 338 340
# Incs: 6.5036 340 527
# Decs: -0.3882 527 533
# Incs: 0.0 533 534
# Decs: -2.7836 534 729
# Incs: 3.3967 729 782
# Decs: -1.6639 782 872
# Incs: 4.6941 872 1040
# Decs: -28.9216 1040 1041
# Incs: 5.7884 1041 1047
# Decs: -29.144 1047 1048
# Incs: 8.8166 1048 1062
# Decs: -33.6386 1062 1063
# Incs: 6.5818 1063 1212
# Decs: -0.6958 1212 1295
# Incs: 0.0502 1295 1299
# Decs: -0.0983 1299 1301
# Incs: 0.0647 1301 1306
# Decs: -0.0546 1306 1307
# Incs: 0.0863 1307 1311
# ...

# %%
a=sorted(a,key=lambda x:x[1],reverse=True)
b=sorted(b,key=lambda x:x[1],reverse=True)

# %%
print("Incs")
print(a)
print("Decs")
print(b)
# Out:
# Incs
# [[12.3433, 8.816642436535714, 1048, 1062], [98.0694, 6.581841568123489, 1063, 1212], [121.6176, 6.503615226404278, 340, 527], [3.473, 5.788360003566713, 1041, 1047], [78.8602, 4.6940607855630985, 872, 1040], [18.0026, 3.396721870239631, 729, 782], [15.2232, 2.5372065484150053, 229, 289], [1.9556, 2.1729136178888866, 202, 211], [0.4691, 1.1728263698499442, 312, 316], [0.3558, 0.8895631026749617, 319, 323], [0.3549, 0.8871606874500948, 305, 309], [0.2474, 0.824764078633263, 298, 301], [0.2213, 0.7376815347999907, 225, 228], [0.1142, 0.5712071576500222, 156, 158], [0.0359, 0.359434624999988, 337, 338], [0.0579, 0.2895033641001632, 197, 199], [0.0238, 0.11912582254991477, 1318, 1320], [0.0183, 0.09160961819976166, 1321, 1323], [0.0345, 0.08625643964998986, 1307, 1311], [0.0323, 0.06468334018006061, 1301, 1306], [0.0201, 0.050240973449966475, 1295, 1299], [0.0002, 0.001541271000160549, 328, 329], [0.0, 9.742699980108682e-06, 533, 534]]
# Decs
# ...

# %%
d.iplot(kind='line',x='sn',y='yaw',size=10)
# Out:
# <div>                            <div id="12220b08-5fb4-4e4b-bbfb-bdfd12a22070" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Out:
# <div>                            <div id="2a225aa3-874d-4c81-8faa-beb37c17636f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d[['lat','lon','alt']].iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="9134f726-1409-4d55-9b81-c25fc6dbdc46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d[['roll','pitch','yaw']].iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="19e67961-5ce5-4cc3-bcaf-f733b1a30ba7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d[['af','al','au']].iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="4ac24622-4c7d-4ff2-b658-93a793e6af1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
d[['vf','vl','vu']].iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="a356c404-8e8e-4ba7-a416-2fe720e5d6fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
